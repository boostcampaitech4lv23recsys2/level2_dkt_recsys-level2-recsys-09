# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# File /opt/conda/lib/python3.8/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File /opt/conda/lib/python3.8/site-packages/pandas/compat/__init__.py:18
#      15 from typing import TYPE_CHECKING
#      17 from pandas._typing import F
# ---> 18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
# ...

# %%
train = pd.read_csv('~/input/DKT/data/train_data.csv', low_memory=False)
test = pd.read_csv('~/input/DKT/data/test_data.csv', low_memory=False)
sub = pd.read_csv('~/input/DKT/data/sample_submission.csv', low_memory=False)

# %% [markdown]
# # EDA

# %%
train['category_2'] = train['assessmentItemID'].str[2]
test['category_2'] = test['assessmentItemID'].str[2]
train['category_3'] = train['assessmentItemID'].str[4:7]
test['category_3'] = test['assessmentItemID'].str[4:7]

# %%
train
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2266581    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2266582    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2266583    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2266584    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2266585    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
# ...
